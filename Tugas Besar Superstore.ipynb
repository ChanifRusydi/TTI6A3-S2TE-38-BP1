# %% [markdown]
# ##### This Juptyer notebook is an adaptation this Collab Notebook [here](https://colab.research.google.com/drive/16bHT5fOLXCO-MAIIqGdDUh7QxGirIf0x?usp=sharing)
# ##### The dataset originally coming from [here](https://www.kaggle.com/datasets/vivek468/superstore-dataset-final)

# %%
import pandas as pd
import numpy as np

# %%
superstore_data =  pd.read_excel('data/Superstore/Superstore.xlsx')

# %%
na_count = superstore_data.isna().sum()
print(na_count)
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
data_columns = superstore_data.columns
data_columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
superstore_data['Discount_Rate'] = superstore_data['Discount'] / superstore_data['Sales']
superstore_data['Discount_Rate']
# Out:
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3       0.000470
# 4       0.008941
#           ...
# 9989    0.007921
# 9990    0.000000
# 9991    0.000773
# 9992    0.000000
# 9993    0.000000
# Name: Discount_Rate, Length: 9994, dtype: float64

# %%
# randomly take 125 data from the dataset
# 100 for training and 25 for testing
sample_data = superstore_data.sample(n=125, random_state=1)
sample_data
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 1814    1815  CA-2012-131597 2012-09-14 2012-09-18  Standard Class
# 881      882  CA-2012-129098 2012-10-09 2012-10-13  Standard Class
# 1122    1123  US-2011-147627 2011-01-21 2011-01-27  Standard Class
# 6807    6808  CA-2012-128125 2012-03-31 2012-04-05  Standard Class
# 2911    2912  CA-2011-113929 2011-06-16 2011-06-21  Standard Class
# ...      ...             ...        ...        ...             ...
# 6516    6517  US-2014-116652 2014-09-16 2014-09-20  Standard Class
# 1463    1464  CA-2013-152289 2013-08-27 2013-08-29     First Class
# 254      255  US-2012-159982 2012-11-28 2012-12-04  Standard Class
# 8391    8392  CA-2014-110625 2014-12-24 2014-12-31  Standard Class
# 4879    4880  CA-2014-143567 2014-11-03 2014-11-06    Second Class
#
#      Customer ID        Customer Name      Segment        Country  \
# 1814    SP-20620     Stefania Perrino    Corporate  United States
# 881     DK-13090            Dave Kipp     Consumer  United States
# 1122    HL-15040         Hunter Lopez     Consumer  United States
# 6807    EB-13705           Ed Braxton    Corporate  United States
# 2911    CK-12205  Chloris Kastensmidt     Consumer  United States
# ...          ...                  ...          ...            ...
# 6516    RD-19480          Rick Duston     Consumer  United States
# 1463    LC-16930       Linda Cazamias    Corporate  United States
# 254     DR-12880      Dan Reichenbach    Corporate  United States
# 8391    JB-16045        Julia Barnett  Home Office  United States
# 4879    TB-21175        Thomas Boland    Corporate  United States
#
#                City  ...   Region       Product ID         Category  \
# 1814    Los Angeles  ...     West  FUR-TA-10002607        Furniture
# 881     Springfield  ...    South  OFF-ST-10001321  Office Supplies
# 1122      Jonesboro  ...    South  OFF-AR-10002375  Office Supplies
# 6807        Houston  ...  Central  OFF-PA-10000357  Office Supplies
# 2911      Hempstead  ...     East  OFF-EN-10003286  Office Supplies
# ...             ...  ...      ...              ...              ...
# 6516  San Francisco  ...     West  FUR-FU-10001488        Furniture
# 1463       Pasadena  ...  Central  FUR-CH-10002126        Furniture
# 254         Chicago  ...  Central  FUR-FU-10002505        Furniture
# 8391        Danbury  ...     East  FUR-FU-10001473        Furniture
# 4879      Henderson  ...    South  OFF-EN-10004846  Office Supplies
#
#      Sub-Category                                       Product Name  \
# 1814       Tables                               KI Conference Tables
# 881       Storage        Decoflex Hanging Personal Folder File, Blue
# 1122          Art                                         Newell 351
# 6807        Paper  White Dual Perf Computer Printout Paper, 2700 ...
# 2911    Envelopes                                            Staples
# ...           ...                                                ...
# 6516  Furnishings  Tenex 46" x 60" Computer Anti-Static Chairmat,...
# 1463       Chairs      Hon Deluxe Fabric Upholstered Stacking Chairs
# 254   Furnishings                   Eldon 100 Class Desk Accessories
# 8391  Furnishings                            DAX Wood Document Frame
# 4879    Envelopes  Letter or Legal Size Expandable Poly String Ti...
#
#          Sales Quantity  Discount    Profit  Discount_Rate
# 1814   170.136        3       0.2   -8.5068       0.001176
# 881     30.840        2       0.0    8.3268       0.000000
# 1122    22.960        7       0.0    6.6584       0.000000
# 6807    98.376        3       0.2   35.6613       0.002033
# 2911    41.400        5       0.0   19.4580       0.000000
# ...        ...      ...       ...       ...            ...
# 6516   529.900        5       0.0  105.9800       0.000000
# 1463  1024.716        6       0.3  -29.2776       0.000293
# 254     12.132        9       0.6   -8.4924       0.049456
# 8391    27.460        2       0.0    9.8856       0.000000
# 4879     5.320        2       0.0    2.6068       0.000000
#
# [125 rows x 22 columns]

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
metric_store = dict()

def metric(model_name,y_true, y_pred, store:bool=True) -> dict:
    metrics_dict = {
        'MAE': mean_absolute_error(y_true, y_pred),
        'MSE': mean_squared_error(y_true, y_pred),
        'R2 Score': r2_score(y_true, y_pred)
    }

    if store:
        metric_store[model_name] = metrics_dict
    return metrics_dict

# %%
def store_metric_as_json(metric_store:dict):
    import json
    with open('metrics.json', 'w') as f:
        json.dump(metric_store, f,indent=2)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder

categorical_cols = ['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region', 'Category', 'Sub-Category']
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
encoded_features = encoder.fit_transform(sample_data[categorical_cols])
encoded_df = pd.DataFrame(encoded_features, columns=encoder.get_feature_names_out(categorical_cols))

# Combine the data
data = pd.concat([sample_data.reset_index(drop=True), encoded_df.reset_index(drop=True)], axis=1)
data.drop(columns=categorical_cols + ['Order ID', 'Order Date', 'Ship Date', 'Customer ID', 'Customer Name', 'Product ID', 'Product Name'], inplace=True)

# Define features and target
X = data.drop(columns=['Profit'])
Y = data['Profit']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=5)
knn_model.fit(X_train, Y_train)

# Make predictions
Y_pred = knn_model.predict(X_test)
knn_model_metrics = metric('KNN', Y_test, Y_pred)
knn_model_metrics
# Out:
# {'MAE': 38.65377625, 'MSE': 5282.3167964698005, 'R2 Score': -1.122079393610714}

# %%
from sklearn.svm import SVR

# %%
svm_linear_model = SVR(kernel='linear')
svm_linear_model.fit(X_train, Y_train)

# Make predictions
Y_pred = svm_linear_model.predict(X_test)
svm_linear_model = metric('SVM Linear', Y_test, Y_pred)
svm_linear_model
# Out:
# {'MAE': 23.02001661255968,
#  'MSE': 1500.0550697973836,
#  'R2 Score': 0.3973788253242059}

# %%
svm_rbf_model = SVR(kernel='rbf')
svm_rbf_model.fit(X_train, Y_train)

# Make predictions
Y_pred = svm_rbf_model.predict(X_test)
svm_rbf_model = metric('SVM RBF', Y_test, Y_pred)
svm_rbf_model
# Out:
# {'MAE': 24.072023231201186,
#  'MSE': 2742.5530752098657,
#  'R2 Score': -0.10177325424253802}

# %%
svm_poly_model = SVR(kernel='poly')
svm_poly_model.fit(X_train, Y_train)

# Make predictions
Y_pred = svm_poly_model.predict(X_test)
svm_poly_model = metric('SVM Poly', Y_test, Y_pred)
svm_poly_model
# Out:
# {'MAE': 24.177503380615946,
#  'MSE': 2726.1124132603904,
#  'R2 Score': -0.09516850271313015}

# %%
metric_store
# Out:
# {'KNN': {'MAE': 38.65377625,
#   'MSE': 5282.3167964698005,
#   'R2 Score': -1.122079393610714},
#  'SVM Linear': {'MAE': 23.02001661255968,
#   'MSE': 1500.0550697973836,
#   'R2 Score': 0.3973788253242059},
#  'SVM RBF': {'MAE': 24.072023231201186,
#   'MSE': 2742.5530752098657,
#   'R2 Score': -0.10177325424253802},
#  'SVM Poly': {'MAE': 24.177503380615946,
#   'MSE': 2726.1124132603904,
#   'R2 Score': -0.09516850271313015}}

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, Flatten, InputLayer

# %%
# Reshape data for CNN (Conv1D expects a 3D input: samples, time steps, features)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
# Define the CNN model
cnn_model = Sequential([
        InputLayer(shape=(X_train.shape[1], 1)),
        Conv1D(filters=64, kernel_size=2, activation='relu'),
        Flatten(),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(1)
    ])
# Out:
# 2024-06-12 20:02:17.183737: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-06-12 20:02:17.183888: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2024-06-12 20:02:17.183921: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2024-06-12 20:02:17.184248: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-06-12 20:02:17.184271: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
adam_model = cnn_model
adam_model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
adam_model_history = adam_model.fit(X_train, Y_train, epochs=50, validation_split=0.1, batch_size=32, verbose=2)
adam_Y_pred = adam_model.predict(X_test).flatten()
adam_metrics = metric('CNN Adam', Y_test, adam_Y_pred)
adam_metrics
# Out:
# Epoch 1/50
# 2024-06-12 20:02:19.305907: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 3/3 - 2s - 514ms/step - loss: 6431.3472 - val_loss: 137948.4531
# Epoch 2/50
# 3/3 - 0s - 23ms/step - loss: 6377.5225 - val_loss: 137442.8438
# Epoch 3/50
# 3/3 - 0s - 17ms/step - loss: 6293.8374 - val_loss: 136738.7812
# Epoch 4/50
# 3/3 - 0s - 18ms/step - loss: 6179.0381 - val_loss: 135792.1562
# Epoch 5/50
# 3/3 - 0s - 20ms/step - loss: 6047.7358 - val_loss: 134814.7656
# Epoch 6/50
# 3/3 - 0s - 19ms/step - loss: 5894.8560 - val_loss: 133786.8281
# Epoch 7/50
# 3/3 - 0s - 19ms/step - loss: 5725.8657 - val_loss: 132560.9375
# Epoch 8/50
# 3/3 - 0s - 51ms/step - loss: 5581.3647 - val_loss: 131255.9219
# Epoch 9/50
# 3/3 - 0s - 29ms/step - loss: 5378.1025 - val_loss: 129724.6016
# Epoch 10/50
# 3/3 - 0s - 19ms/step - loss: 5169.4351 - val_loss: 128129.3594
# Epoch 11/50
# 3/3 - 0s - 23ms/step - loss: 4947.3159 - val_loss: 126688.0781
# Epoch 12/50
# 3/3 - 0s - 28ms/step - loss: 4707.4868 - val_loss: 124863.3984
# Epoch 13/50
# 3/3 - 0s - 17ms/step - loss: 4444.0557 - val_loss: 122741.7734
# Epoch 14/50
# 3/3 - 0s - 19ms/step - loss: 4141.0728 - val_loss: 120760.6406
# Epoch 15/50
# 3/3 - 0s - 17ms/step - loss: 3867.8508 - val_loss: 118574.1641
# Epoch 16/50
# 3/3 - 0s - 17ms/step - loss: 3566.0391 - val_loss: 116632.0234
# Epoch 17/50
# 3/3 - 0s - 22ms/step - loss: 3227.0488 - val_loss: 114352.4844
# Epoch 18/50
# 3/3 - 0s - 19ms/step - loss: 2996.7229 - val_loss: 111683.4531
# Epoch 19/50
# 3/3 - 0s - 23ms/step - loss: 2732.2883 - val_loss: 109421.5625
# Epoch 20/50
# 3/3 - 0s - 23ms/step - loss: 2430.2876 - val_loss: 107149.1250
# Epoch 21/50
# 3/3 - 0s - 32ms/step - loss: 2203.9451 - val_loss: 105367.6016
# Epoch 22/50
# 3/3 - 0s - 26ms/step - loss: 1956.4327 - val_loss: 103333.8281
# Epoch 23/50
# 3/3 - 0s - 17ms/step - loss: 1828.2223 - val_loss: 101922.7812
# Epoch 24/50
# 3/3 - 0s - 20ms/step - loss: 1698.1798 - val_loss: 100655.5156
# Epoch 25/50
# 3/3 - 0s - 20ms/step - loss: 1431.8157 - val_loss: 101645.2344
# Epoch 26/50
# 3/3 - 0s - 21ms/step - loss: 1294.2197 - val_loss: 99441.7344
# Epoch 27/50
# 3/3 - 0s - 18ms/step - loss: 1215.4237 - val_loss: 99598.0469
# Epoch 28/50
# 3/3 - 0s - 20ms/step - loss: 1073.2408 - val_loss: 101635.5781
# Epoch 29/50
# 3/3 - 0s - 17ms/step - loss: 994.5518 - val_loss: 98912.3359
# Epoch 30/50
# 3/3 - 0s - 16ms/step - loss: 963.2505 - val_loss: 100110.1484
# Epoch 31/50
# 3/3 - 0s - 17ms/step - loss: 938.6731 - val_loss: 101289.8984
# Epoch 32/50
# 3/3 - 0s - 25ms/step - loss: 865.7151 - val_loss: 97842.8906
# Epoch 33/50
# 3/3 - 0s - 75ms/step - loss: 779.3881 - val_loss: 101453.1562
# Epoch 34/50
# 3/3 - 0s - 29ms/step - loss: 704.6052 - val_loss: 99678.0234
# Epoch 35/50
# 3/3 - 0s - 20ms/step - loss: 686.7416 - val_loss: 99170.9531
# Epoch 36/50
# 3/3 - 0s - 19ms/step - loss: 586.1526 - val_loss: 101985.5781
# Epoch 37/50
# 3/3 - 0s - 19ms/step - loss: 612.0286 - val_loss: 100455.5859
# Epoch 38/50
# 3/3 - 0s - 18ms/step - loss: 564.5074 - val_loss: 100212.6484
# Epoch 39/50
# 3/3 - 0s - 18ms/step - loss: 526.1755 - val_loss: 102143.7031
# Epoch 40/50
# 3/3 - 0s - 20ms/step - loss: 527.4747 - val_loss: 101893.9766
# Epoch 41/50
# 3/3 - 0s - 21ms/step - loss: 480.5495 - val_loss: 102832.4219
# Epoch 42/50
# 3/3 - 0s - 21ms/step - loss: 469.4608 - val_loss: 102683.8281
# Epoch 43/50
# 3/3 - 0s - 24ms/step - loss: 458.8135 - val_loss: 102978.8828
# Epoch 44/50
# 3/3 - 0s - 21ms/step - loss: 443.3941 - val_loss: 104986.4609
# Epoch 45/50
# 3/3 - 0s - 19ms/step - loss: 426.8813 - val_loss: 103704.6094
# Epoch 46/50
# 3/3 - 0s - 19ms/step - loss: 427.9179 - val_loss: 104778.1406
# Epoch 47/50
# 3/3 - 0s - 16ms/step - loss: 400.7659 - val_loss: 105296.5625
# Epoch 48/50
# 3/3 - 0s - 17ms/step - loss: 404.1246 - val_loss: 104460.2656
# Epoch 49/50
# 3/3 - 0s - 17ms/step - loss: 373.9547 - val_loss: 105818.5469
# Epoch 50/50
# 3/3 - 0s - 22ms/step - loss: 371.8726 - val_loss: 104889.8281
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# {'MAE': 56.02283037846088,
#  'MSE': 5642.118606862508,
#  'R2 Score': -1.266623546685453}

# %%
sgd_model = cnn_model
sgd_model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001), loss='mse')
sgd_model_history = sgd_model.fit(X_train, Y_train, epochs=50, validation_split=0.1, batch_size=32, verbose=2)
sgd_Y_pred = sgd_model.predict(X_test).flatten()

sgd_metrics = metric('CNN SGD', Y_test, sgd_Y_pred)
sgd_metrics
# Out:
# Epoch 1/50
# 3/3 - 1s - 168ms/step - loss: 30638786.0000 - val_loss: 26135206.0000
# Epoch 2/50
# 3/3 - 0s - 14ms/step - loss: 10555461.0000 - val_loss: 136939.3125
# Epoch 3/50
# 3/3 - 0s - 17ms/step - loss: 6308.9761 - val_loss: 136897.2188
# Epoch 4/50
# 3/3 - 0s - 14ms/step - loss: 6305.4580 - val_loss: 136865.0000
# Epoch 5/50
# 3/3 - 0s - 17ms/step - loss: 6302.6211 - val_loss: 136836.1250
# Epoch 6/50
# 3/3 - 0s - 13ms/step - loss: 6301.0830 - val_loss: 136805.0312
# Epoch 7/50
# 3/3 - 0s - 13ms/step - loss: 6298.4600 - val_loss: 136762.5781
# Epoch 8/50
# 3/3 - 0s - 12ms/step - loss: 6294.7471 - val_loss: 136727.5625
# Epoch 9/50
# 3/3 - 0s - 14ms/step - loss: 6291.8745 - val_loss: 136696.3125
# Epoch 10/50
# 3/3 - 0s - 13ms/step - loss: 6289.8501 - val_loss: 136661.0312
# Epoch 11/50
# 3/3 - 0s - 12ms/step - loss: 6287.3218 - val_loss: 136637.3438
# Epoch 12/50
# 3/3 - 0s - 13ms/step - loss: 6285.2612 - val_loss: 136602.2031
# Epoch 13/50
# 3/3 - 0s - 18ms/step - loss: 6284.1860 - val_loss: 136587.2812
# Epoch 14/50
# 3/3 - 0s - 14ms/step - loss: 6281.9712 - val_loss: 136557.8594
# Epoch 15/50
# 3/3 - 0s - 14ms/step - loss: 6279.8438 - val_loss: 136513.2812
# Epoch 16/50
# 3/3 - 0s - 15ms/step - loss: 6276.7031 - val_loss: 136471.7188
# Epoch 17/50
# 3/3 - 0s - 16ms/step - loss: 6273.5615 - val_loss: 136426.3125
# Epoch 18/50
# 3/3 - 0s - 13ms/step - loss: 6270.3374 - val_loss: 136379.9531
# Epoch 19/50
# 3/3 - 0s - 14ms/step - loss: 6268.3345 - val_loss: 136338.2031
# Epoch 20/50
# 3/3 - 0s - 17ms/step - loss: 6267.2329 - val_loss: 136276.0781
# Epoch 21/50
# 3/3 - 0s - 13ms/step - loss: 6262.5273 - val_loss: 136254.5938
# Epoch 22/50
# 3/3 - 0s - 12ms/step - loss: 6259.5610 - val_loss: 136192.0938
# Epoch 23/50
# 3/3 - 0s - 13ms/step - loss: 6257.8691 - val_loss: 136173.2656
# Epoch 24/50
# 3/3 - 0s - 13ms/step - loss: 6255.0088 - val_loss: 136134.0938
# Epoch 25/50
# 3/3 - 0s - 13ms/step - loss: 6253.8813 - val_loss: 136085.4688
# Epoch 26/50
# 3/3 - 0s - 24ms/step - loss: 6251.0078 - val_loss: 136028.6719
# Epoch 27/50
# 3/3 - 0s - 13ms/step - loss: 6247.7705 - val_loss: 135998.5938
# Epoch 28/50
# 3/3 - 0s - 12ms/step - loss: 6248.1245 - val_loss: 135986.4688
# Epoch 29/50
# 3/3 - 0s - 12ms/step - loss: 6244.5347 - val_loss: 135940.2031
# Epoch 30/50
# 3/3 - 0s - 12ms/step - loss: 6243.2476 - val_loss: 135912.4375
# Epoch 31/50
# 3/3 - 0s - 13ms/step - loss: 6241.2979 - val_loss: 135869.4688
# Epoch 32/50
# 3/3 - 0s - 15ms/step - loss: 6238.1763 - val_loss: 135801.0469
# Epoch 33/50
# 3/3 - 0s - 13ms/step - loss: 6236.9897 - val_loss: 135736.6250
# Epoch 34/50
# 3/3 - 0s - 13ms/step - loss: 6232.3457 - val_loss: 135664.2188
# Epoch 35/50
# 3/3 - 0s - 30ms/step - loss: 6229.8389 - val_loss: 135629.3750
# Epoch 36/50
# 3/3 - 0s - 17ms/step - loss: 6228.5122 - val_loss: 135575.3594
# Epoch 37/50
# 3/3 - 0s - 15ms/step - loss: 6230.6372 - val_loss: 135462.9844
# Epoch 38/50
# 3/3 - 0s - 14ms/step - loss: 6221.5342 - val_loss: 135387.2188
# Epoch 39/50
# 3/3 - 0s - 16ms/step - loss: 6219.6968 - val_loss: 135313.8594
# Epoch 40/50
# 3/3 - 0s - 14ms/step - loss: 6216.6611 - val_loss: 135245.2188
# Epoch 41/50
# 3/3 - 0s - 13ms/step - loss: 6215.2559 - val_loss: 135222.3594
# Epoch 42/50
# 3/3 - 0s - 12ms/step - loss: 6215.2388 - val_loss: 135173.4219
# Epoch 43/50
# 3/3 - 0s - 12ms/step - loss: 6213.8545 - val_loss: 135140.6562
# Epoch 44/50
# 3/3 - 0s - 12ms/step - loss: 6211.9199 - val_loss: 135100.1250
# Epoch 45/50
# 3/3 - 0s - 17ms/step - loss: 6219.7378 - val_loss: 135161.9531
# Epoch 46/50
# 3/3 - 0s - 13ms/step - loss: 6214.3359 - val_loss: 135151.0781
# Epoch 47/50
# 3/3 - 0s - 104ms/step - loss: 6212.8379 - val_loss: 135065.2812
# Epoch 48/50
# 3/3 - 0s - 91ms/step - loss: 6220.3608 - val_loss: 134919.9688
# Epoch 49/50
# 3/3 - 0s - 38ms/step - loss: 6212.8945 - val_loss: 134845.1406
# Epoch 50/50
# 3/3 - 0s - 27ms/step - loss: 6207.9932 - val_loss: 134813.3281
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# {'MAE': 24.674308622932436,
#  'MSE': 2584.637497559168,
#  'R2 Score': -0.03833340272007102}

# %%
rmsprop_model = cnn_model
rmsprop_model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001), loss='mse')
rmsprop_model_history = rmsprop_model.fit(X_train, Y_train, epochs=50, validation_split=0.1, batch_size=32, verbose=2)
rmsprop_Y_pred = rmsprop_model.predict(X_test).flatten()

rmsprop_metrics = metric('CNN RMSprop', Y_test, rmsprop_Y_pred)
rmsprop_metrics
# Out:
# Epoch 1/50
# 3/3 - 1s - 213ms/step - loss: 6222.8950 - val_loss: 134830.5000
# Epoch 2/50
# 3/3 - 0s - 14ms/step - loss: 6211.7803 - val_loss: 134881.9062
# Epoch 3/50
# 3/3 - 0s - 15ms/step - loss: 6219.4111 - val_loss: 134781.8281
# Epoch 4/50
# 3/3 - 0s - 16ms/step - loss: 6209.1211 - val_loss: 134817.3906
# Epoch 5/50
# 3/3 - 0s - 14ms/step - loss: 6207.7891 - val_loss: 134840.6406
# Epoch 6/50
# 3/3 - 0s - 21ms/step - loss: 6213.1392 - val_loss: 134910.3594
# Epoch 7/50
# 3/3 - 0s - 13ms/step - loss: 6217.1011 - val_loss: 134936.4375
# Epoch 8/50
# 3/3 - 0s - 13ms/step - loss: 6208.8975 - val_loss: 134929.3125
# Epoch 9/50
# 3/3 - 0s - 13ms/step - loss: 6208.7988 - val_loss: 134914.4531
# Epoch 10/50
# 3/3 - 0s - 13ms/step - loss: 6208.0122 - val_loss: 134843.4062
# Epoch 11/50
# 3/3 - 0s - 13ms/step - loss: 6207.5264 - val_loss: 134780.6875
# Epoch 12/50
# 3/3 - 0s - 13ms/step - loss: 6208.2935 - val_loss: 134798.3750
# Epoch 13/50
# 3/3 - 0s - 12ms/step - loss: 6214.1484 - val_loss: 134792.7656
# Epoch 14/50
# 3/3 - 0s - 13ms/step - loss: 6206.1401 - val_loss: 134731.6094
# Epoch 15/50
# 3/3 - 0s - 13ms/step - loss: 6213.9238 - val_loss: 134594.2188
# Epoch 16/50
# 3/3 - 0s - 15ms/step - loss: 6205.2188 - val_loss: 134615.3594
# Epoch 17/50
# 3/3 - 0s - 13ms/step - loss: 6208.5698 - val_loss: 134551.3438
# Epoch 18/50
# 3/3 - 0s - 15ms/step - loss: 6217.4727 - val_loss: 134673.7031
# Epoch 19/50
# 3/3 - 0s - 16ms/step - loss: 6211.4292 - val_loss: 134697.9062
# Epoch 20/50
# 3/3 - 0s - 16ms/step - loss: 6210.2476 - val_loss: 134597.8438
# Epoch 21/50
# 3/3 - 0s - 14ms/step - loss: 6211.4346 - val_loss: 134608.7812
# Epoch 22/50
# 3/3 - 0s - 12ms/step - loss: 6204.8857 - val_loss: 134629.5938
# Epoch 23/50
# 3/3 - 0s - 13ms/step - loss: 6205.4321 - val_loss: 134584.9688
# Epoch 24/50
# 3/3 - 0s - 13ms/step - loss: 6206.7427 - val_loss: 134505.5938
# Epoch 25/50
# 3/3 - 0s - 12ms/step - loss: 6211.0605 - val_loss: 134571.0000
# Epoch 26/50
# 3/3 - 0s - 15ms/step - loss: 6210.9468 - val_loss: 134521.1250
# Epoch 27/50
# 3/3 - 0s - 16ms/step - loss: 6222.2847 - val_loss: 134527.0469
# Epoch 28/50
# 3/3 - 0s - 13ms/step - loss: 6220.2231 - val_loss: 134671.9844
# Epoch 29/50
# 3/3 - 0s - 13ms/step - loss: 6208.8257 - val_loss: 134729.7188
# Epoch 30/50
# 3/3 - 0s - 15ms/step - loss: 6206.7476 - val_loss: 134670.3594
# Epoch 31/50
# 3/3 - 0s - 12ms/step - loss: 6209.4990 - val_loss: 134718.1406
# Epoch 32/50
# 3/3 - 0s - 13ms/step - loss: 6206.5464 - val_loss: 134699.1250
# Epoch 33/50
# 3/3 - 0s - 12ms/step - loss: 6209.0098 - val_loss: 134614.7031
# Epoch 34/50
# 3/3 - 0s - 12ms/step - loss: 6210.3945 - val_loss: 134621.5625
# Epoch 35/50
# 3/3 - 0s - 13ms/step - loss: 6204.6079 - val_loss: 134575.4531
# Epoch 36/50
# 3/3 - 0s - 13ms/step - loss: 6211.9941 - val_loss: 134601.7500
# Epoch 37/50
# 3/3 - 0s - 13ms/step - loss: 6209.4146 - val_loss: 134628.0156
# Epoch 38/50
# 3/3 - 0s - 12ms/step - loss: 6224.1289 - val_loss: 134596.3438
# Epoch 39/50
# 3/3 - 0s - 12ms/step - loss: 6208.3525 - val_loss: 134500.8125
# Epoch 40/50
# 3/3 - 0s - 13ms/step - loss: 6208.5288 - val_loss: 134457.4688
# Epoch 41/50
# 3/3 - 0s - 12ms/step - loss: 6210.1240 - val_loss: 134515.9844
# Epoch 42/50
# 3/3 - 0s - 13ms/step - loss: 6218.2891 - val_loss: 134518.9062
# Epoch 43/50
# 3/3 - 0s - 13ms/step - loss: 6205.5742 - val_loss: 134566.1562
# Epoch 44/50
# 3/3 - 0s - 13ms/step - loss: 6211.2217 - val_loss: 134517.4219
# Epoch 45/50
# 3/3 - 0s - 14ms/step - loss: 6203.6587 - val_loss: 134510.1875
# Epoch 46/50
# 3/3 - 0s - 14ms/step - loss: 6207.7100 - val_loss: 134493.6562
# Epoch 47/50
# 3/3 - 0s - 13ms/step - loss: 6219.1279 - val_loss: 134476.3750
# Epoch 48/50
# 3/3 - 0s - 12ms/step - loss: 6214.0791 - val_loss: 134480.1250
# Epoch 49/50
# 3/3 - 0s - 13ms/step - loss: 6204.8574 - val_loss: 134494.1875
# Epoch 50/50
# 3/3 - 0s - 12ms/step - loss: 6206.5557 - val_loss: 134424.8906
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# {'MAE': 24.990952102279664,
#  'MSE': 2554.684101816606,
#  'R2 Score': -0.026300144147537452}
